# %%
print("Python Programmming Fundamentals")
# Out:
# Python Programmming Fundamentals

# %%
print("Hello", "Class")
# Out:
# Hello Class

# %%
print(100)
# Out:
# 100

# %%
print(100,200,300,400)
# Out:
# 100 200 300 400

# %%
print(100, "i am text")
# Out:
# 100 i am text

# %%
print(100,200,300,400, sep="####")
# Out:
# 100####200####300####400

# %% [markdown]
# # Data
#  - Numbers
#  - Text

# %% [markdown]
# # Data Types
#     - Numbers
#         - Whole    : itnegers  >>> int
#         - Decimal  : flaots    >>> float
#
#     - Text
#          - "cahracter/word/sentence/paragraph":  strings : str
#     - Boolean     : true /false : bool (True /False)

# %%
print("Hello we are  learning Python")
# Out:
# Hello we are  learning Python

# %%
print("100")
# Out:
# 100

# %%
print(23.6)
# Out:
# 23.6

# %%
print(200)
# Out:
# 200

# %%
print(type(200))
# Out:
# <class 'int'>

# %%
print(type(23.6))
# Out:
# <class 'float'>

# %%
print(type("Hello we are  learning Python"))
# Out:
# <class 'str'>

# %%
print(type(True))
# Out:
# <class 'bool'>

# %% [markdown]
# # Variables

# %%
course  = "Data  Sciences and AI"

# %%
course
# Out:
# 'Data  Sciences and AI'

# %%
course = "Python for Ai and Data Sciences"

# %%
course
# Out:
# 'Python for Ai and Data Sciences'

# %%
marks  = 100

# %%
type(marks)
# Out:
# int

# %% [markdown]
# # Variable Naming

# %%
# variable name shpould not start with a number 
1student = "Ali"
# Out:
#   Cell In[23], line 2
#     1student = "Ali"
#     ^
# SyntaxError: invalid decimal literal

# %%
# no special charaters are allowed. 
father@name = "asad"
father-name = "asad"
father.name = "asad"
father$name = "asad"
# Out:
#   Cell In[24], line 2
#     father@name = "asad"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
#space not allowed in variable name
father name = "asad"
student name = "asad"
# Out:
#   Cell In[25], line 2
#     father name = "asad"
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Reserved words: no resrved words can be uaed as a variable name
# ![image.png](attachment:image.png)

# %% [markdown]
# # Operator
#     - - (subtraction)
#     - + (addition)
#     - * (
#     - /
#     - //
#     - %
#     - =
#     - ** exponent

# %%
4+6
# Out:
# 10

# %%
4 - 9
# Out:
# -5

# %%
5*5
# Out:
# 25

# %%
5**3
# Out:
# 125

# %%
# floating divsion
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3 # floor disivon integer
# Out:
# 3

# %%
10.2//4
# Out:
# 2.0

# %% [markdown]
# # % modulus operator
#         - remainder

# %%
12%6
# Out:
# 0

# %% [markdown]
# # Assignment Operator

# %%
total = 120

# a integer value 120 is asssigned to a variable named total

# %% [markdown]
# # Comparision Operator
# ###     -  ==
# ###       - !=
# ###       - >
# ###       - <
# ###       - >=
# ###       - <=

# %%
marks = 100
obtained = 67

# %%
marks > obtained
# Out:
# True

# %%
marks < obtained
# Out:
# False

# %%
marks >= obtained
# Out:
# True

# %%
marks<= obtained
# Out:
# False

# %%
marks == obtained
# Out:
# False

# %%
marks!=obtained
# Out:
# True

# %% [markdown]
# # User Input

# %%
input("please tell me your age")
# Out:
# please tell me your age12
# '12'

# %%
age  = input("please tell me your age")
# Out:
# please tell me your age120

# %%
type(age)
# Out:
# str

# %%
age + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 age + 10
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Type Casting

# %%
int(133.5)
# Out:
# 133

# %%
float(12)
# Out:
# 12.0

# %%
int("100")
# Out:
# 100

# %%
str(100)
# Out:
# '100'

# %%
float("45.6")
# Out:
# 45.6

# %%
int(float("45.6"))
# Out:
# 45

# %%
age  = int(input("Enter your age"))
age+10
# Out:
# Enter your age45
# 55

# %%
age = age+ 10
age
# Out:
# 75

# %% [markdown]
# # Incrment Operator / Decrement Operator

# %%
count  = 1

# %%
count = count+1
count
# Out:
# 5

# %%
count +=5
count
# Out:
# 30

# %%
count -=5
count
# Out:
# 0

# %% [raw]
# Imran Khan was born in Lahore on 5 October 1952.
# Imran Ahmed Khan Niazi is a Pakistani politician and former cricketer
# who served as the 22nd prime minister of Pakistan from August 2018
# until April 2022. He is the founder and former chairman of the
# political party Pakistan Tehreek-e-Insaf from 1996 to 2023.

# %%
name  = "Imran Khan"
dob = 1952
citizenship = "Paksitani"
profession1 = "Cricketer"
profession2 = "Politician"
age  = 2024- dob
